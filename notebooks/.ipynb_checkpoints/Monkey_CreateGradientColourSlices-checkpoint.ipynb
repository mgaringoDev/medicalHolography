# %% [markdown]
# # Table of Contents

# %% [markdown]
# # Background

# %% [markdown]
# We had a meeting on Feb 02nd, 2019 and Michael suggested the following to create the first hologram:
# - Red to green transition - texture map them
# - Each slice is a different colour (colouring) red to yellow/green
# - Marcus just needs to put this colours to denote tissue density or difference in tissue
#
# These are some helpful links that I will be using in this notebook
# - Plotly method of showing MRI slices found [here](https://plot.ly/python/visualizing-mri-volume-slices/ )
# - Gif of showing slices found [here](https://www.datacamp.com/community/tutorials/matplotlib-3d-volumetric-data)

# %% [markdown]
# # Imports

# %%
import os
import numpy
import SimpleITK
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scipy.ndimage
import scipy.misc
from skimage import color, io, img_as_float

# %% [markdown]
# gif generation lib

# %%
import imageio

# %% [markdown]
# # Functions

# %%
def sitk_show(img, title=None, margin=0.05, dpi=40 ):
    nda = SimpleITK.GetArrayFromImage(img)
    spacing = img.GetSpacing()
    figsize = (1 + margin) * nda.shape[0] / dpi, (1 + margin) * nda.shape[1] / dpi
    extent = (0, nda.shape[1]*spacing[1], nda.shape[0]*spacing[0], 0)
    fig = plt.figure(figsize=figsize, dpi=dpi)
    ax = fig.add_axes([margin, margin, 1 - 2*margin, 1 - 2*margin])

    plt.set_cmap("gray")
    ax.imshow(nda,extent=extent,interpolation=None)
    
    if title:
        plt.title(title)
    
    plt.show()

# %%
def showSegmentation(sliceNum=90):
    # Get slice
    idxSlice = sliceNum
    imgOriginal = image[:,:,idxSlice]

    # Apply smoothing
    imgSmooth = SimpleITK.CurvatureFlow(image1=imgOriginal,
                                        timeStep=0.125,
                                        numberOfIterations=5)
    sitk_show(imgSmooth)

    # Get segmentation
    lstSeeds = [(75,60)]

    imgWhiteMatter = SimpleITK.ConnectedThreshold(image1=imgSmooth, 
                                                  seedList=lstSeeds, 
                                                  lower=0, 
                                                  upper=40,
                                                  replaceValue=labelWhiteMatter)

    # Rescale 'imgSmooth' and cast it to an integer type to match that of 'imgWhiteMatter'
    imgSmoothInt = SimpleITK.Cast(SimpleITK.RescaleIntensity(imgSmooth), imgWhiteMatter.GetPixelID())

    # Use 'LabelOverlay' to overlay 'imgSmooth' and 'imgWhiteMatter'
    sitk_show(SimpleITK.LabelOverlay(imgSmoothInt, imgWhiteMatter))

    # show segmentation
    sitk_show(imgWhiteMatter)

# %%
def getSmoothenImage(img):
    imgSmoothed = SimpleITK.CurvatureFlow(image1=img,
        timeStep=0.125,
        numberOfIterations=5)
    return imgSmoothed

# %%
def sitk_showColour(img, title=None, margin=0.05, dpi=40,cmapType="gray" ):
    nda = SimpleITK.GetArrayFromImage(img)
    spacing = img.GetSpacing()
    figsize = (1 + margin) * nda.shape[0] / dpi, (1 + margin) * nda.shape[1] / dpi
    extent = (0, nda.shape[1]*spacing[1], nda.shape[0]*spacing[0], 0)
    fig = plt.figure(figsize=figsize, dpi=dpi)
    ax = fig.add_axes([margin, margin, 1 - 2*margin, 1 - 2*margin])

    plt.set_cmap(cmapType)
    ax.imshow(nda,extent=extent,interpolation=None)
    
    if title:
        plt.title(title)
    
    plt.show()

# %% [markdown]
# # Parameters

# %%
inpath = 'C://Cerebral//_MarioSandBox//DB//medicalHolography//Monkey//10 sample Chimpanzee 3T for NCBR website//Male_Fritz.nii'
# inpath = "C://Cerebral//_MarioSandBox//DB//medicalHolography//UofT Mouse Brain//C57brain.mnc"

# %%
# Z slice of the DICOM files to process. In the interest of
# simplicity, segmentation will be limited to a single 2D
# image but all processes are entirely applicable to the 3D image
idxSlice = 50

# int labels to assign to the segmented white and gray matter.
# These need to be different integers but their values themselves
# don't matter
labelWhiteMatter = 1
labelGrayMatter = 2

# %% [markdown]
# # Reading Data

# %%
reader = SimpleITK.ImageFileReader()
image = SimpleITK.ReadImage(inpath)

# %% [markdown]
# # Display the data

# %%
idxSlice = 50
imgOriginal = image[:,:,idxSlice]
sitk_show(imgOriginal)

# %% [markdown]
# # Smoothing

# %%
imgSmooth = SimpleITK.CurvatureFlow(image1=imgOriginal,
                                    timeStep=0.125,
                                    numberOfIterations=5)

# blurFilter = SimpleITK.CurvatureFlowImageFilter()
# blurFilter.SetNumberOfIterations(5)
# blurFilter.SetTimeStep(0.125)
# imgSmooth = blurFilter.Execute(imgOriginal)

sitk_show(imgSmooth)

# %% [markdown]
# We are basically just smoothing the images so that it doesn't have that grainy look to it.

# %%
imgSmoothFun = getSmoothenImage(imgOriginal)

sitk_show(imgSmoothFun)

# %% [markdown]
# # Colour Mapping Variants

# %% [markdown]
# ## Regular Gray Scale Image

# %%
colMap = ["gray"]

# %%
sitk_showColour(imgSmoothFun,title=colMap[0]+' Scale Image',cmapType=colMap[0])

# %% [markdown]
# ## Gradients

# %%
imageStackNumpy = []
for currentSliceInd in xrange(numSlices):
    currentSlice = image[:,:,currentSliceInd]
    currentSliceSmoothed = getSmoothenImage(currentSlice)
    numpyArraySlice = SimpleITK.GetArrayFromImage(currentSliceSmoothed)
    imageStackNumpy.append(numpyArraySlice)

# %% [markdown]
# To apply a mask I used the following tutorial in a [stackoverflow thread](https://stackoverflow.com/questions/9193603/applying-a-coloured-overlay-to-an-image-in-either-pil-or-imagemagik)

# %% [markdown]
# The gradient is supposed to go from red to green.  We can manipulate the alpha in n steps and then switch to a green mask after m number of steps.  So alpha will go from lets say 0.8-0.1 using the red mask and the 0.1-0.8 using the green mask.  Since there are 128 slices. We can set a threshold at 64.  When this hits we can switch from one colour to the next and also start to increment the mask alpha

# %%
alpha = 0.8
th = numSlices/2
maxAlapha = alpha
minAlpha = 0.2
rangeAlpha = maxAlapha-minAlpha
incrementalAlpha = rangeAlpha/th

# %%
maskedImage = []
for sliceInd in xrange(numSlices):    
        
    # get the image
    imgRaw = imageStackNumpy[sliceInd]
    img = imgRaw/imgRaw.max()
    rows, cols = img.shape
    color_mask = np.zeros((rows, cols, 3))
    
    # contruct colour image to superimpose
    if(sliceInd<th):
        #red
        alpha = alpha - incrementalAlpha         
        color_mask[0:rows-1, 0:cols-1] = [1, 0, 0]  # Red block
    else:
        #green
        alpha = alpha + incrementalAlpha         
        color_mask[0:rows-1, 0:cols-1] = [0, 1, 0]  # Red block
    
    # Construct RGB version of grey-level image
    img_color = np.dstack((img, img, img))
    
    # Convert the input image and color mask to Hue Saturation Value (HSV)
    # colorspace
    img_hsv = color.rgb2hsv(img_color)
    color_mask_hsv = color.rgb2hsv(color_mask)

    # Replace the hue and saturation of the original image
    # with that of the color mask
    img_hsv[..., 0] = color_mask_hsv[..., 0]
    img_hsv[..., 1] = color_mask_hsv[..., 1] * alpha

    img_masked = color.hsv2rgb(img_hsv)
    
    maskedImage.append(img_masked)

# %% [markdown]
# # Gif Generation

# %%
dirGifOutput = "C://Cerebral//_MarioSandBox//DB//medicalHolography//Animal Brains//Monkey//gifs//"

# %% [markdown]
# ## No Gradient Colour

# %%
numSlices = image.GetDepth()

# %%
imageStack = []
for currentSliceInd in xrange(numSlices):
    currentSlice = image[:,:,currentSliceInd]
    currentSliceSmoothed = getSmoothenImage(currentSlice)
    numpyArraySlice = SimpleITK.GetArrayFromImage(currentSliceSmoothed)
    imageStack.append(numpyArraySlice)

# %%
imageio.mimsave(dirGifOutput+'fritz.gif',imageStack)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 165.747850063]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 143.118564229]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 111.128207463]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 109.302811551]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 119.936130794]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 138.074936235]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 136.941629246]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 147.648712871]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 144.893829697]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 153.99437214]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 181.583721156]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 185.13189109]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 198.704506797]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 193.192479493]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 202.146764785]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 198.948528409]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 205.021331815]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 208.49039438]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 211.533054387]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 213.446066604]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 235.324100867]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 227.639089659]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 231.182334504]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 233.524348867]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 234.051716568]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 260.213218264]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 251.02762593]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 246.357115764]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 243.138192248]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 249.319720169]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 260.655814993]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 276.494222871]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 272.290927223]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 275.512202229]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 280.887627867]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 266.132744693]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 261.706587928]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 275.08907988]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 276.745639012]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 280.625775041]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 276.841199148]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 292.848118977]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 286.862555887]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 296.310162291]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 288.854370606]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 285.608587049]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 278.746750805]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 273.911414517]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 271.339539923]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 283.320085694]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 294.341997231]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 273.597902115]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 254.057082478]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 248.346695002]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 257.042587063]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 248.451699878]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 240.95354655]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0, 236.513534652]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0.0,