# %% [markdown]
# # Imports

# %%
import numpy as np
import scipy.io 
import pandas as  pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # DB

# %%
workingDir = 'C:/Cerebral/_MarioSandBox/DB/medicalHolography/vascular/Example/'
dataName = 'VTD_ready_for_ROI_choice.mat'
maskName = 'mask.mat'

# %%
def readData(fileLocationAndName,VariableName):
    data = scipy.io.loadmat(fileLocationAndName)
    data = data[VariableName]
    dataArray = np.array(data)
    return dataArray

# %%
data = readData(workingDir+dataName,'VTD_ready')
data.shape
# Out:
# (360L, 766L, 760L)

# %%
mask = readData(workingDir+maskName,'mask')
mask.shape
# Out:
# (760L, 766L)

# %% [markdown]
# # Functions

# %%
def drawSlice(stack,sliceIndex):
    plt.figure()
    plt.imshow(stack[sliceIndex].T)

# %%
def sample_stack(stack, rows=6, cols=6, start_with=10, show_every=3):
    fig,ax = plt.subplots(rows,cols,figsize=[12,12])
    for i in range(rows*cols):
        ind = start_with + i*show_every
        ax[int(i/rows),int(i % rows)].set_title('slice %d' % ind)
        ax[int(i/rows),int(i % rows)].imshow(stack[ind].T,cmap='jet')
        ax[int(i/rows),int(i % rows)].axis('off')
    plt.show()

# %% [markdown]
# # Lets View the Data

# %%
sample_stack(data)

# %%
sliceIndex = 70
drawSlice(data,sliceIndex)
